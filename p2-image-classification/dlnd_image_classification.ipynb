# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [04:22, 650KB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-e51b22fafd96> in <module>()
#       2 get_ipython().magic("config InlineBackend.figure_format = 'retina'")
#       3
# ----> 4 import helper
#       5 import numpy as np
#       6
#
# C:\Users\dell\Documents\GitHub\deep-learning-nd\p2-image-classification\helper.py in <module>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.preprocessing import LabelBinarizer
#       5
#       6
#
# ImportError: No module named 'sklearn'

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x_min = np.min(x)
    x_max = np.max(x)
    return (x - x_min)/(x_max - x_min)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

n_classes = 10
encoding_map = range(n_classes)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    lb = preprocessing.LabelBinarizer()
    lb.fit(encoding_map)
    x = lb.transform(x)
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    x = tf.placeholder(tf.float32, shape=(None, *image_shape), name="x")
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, shape=(None, n_classes), name="y")
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def weight_variable(shape):
  initial = tf.truncated_normal(shape)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W, conv_strides):
    return tf.nn.conv2d(x, W, strides=[1,*conv_strides, 1], padding='VALID')

def maxpool2d(x, pool_ksize, pool_strides):
    return tf.nn.max_pool(x, ksize=[1, *pool_ksize, 1],strides=[1, *pool_strides, 1], padding='VALID')


def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #conv_ksize contains the filter_height, filter_width, 
    #conv_num_outputs : this is the output depth
        
    batch_size, width, height, depth = x_tensor.shape
    input_depth = int(depth)
    
    # The shape of the filter weight is (height, width, input_depth, output_depth)
    weights_shape = [*conv_ksize, input_depth, conv_num_outputs]
    filter_weights = weight_variable(weights_shape)
    
    # The shape of the biases is equal the the number of outputs of the conv layer
    filter_biases = bias_variable([conv_num_outputs])
    
    layer = conv2d(x_tensor, filter_weights, conv_strides) + filter_biases
    layer = maxpool2d(layer, pool_ksize, pool_strides)
    return layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
        
    layer = conv2d_maxpool(x_tensor=x, 
                           conv_num_outputs=10, 
                           conv_ksize=(2,2), 
                           conv_strides=(4,4), 
                           pool_ksize=(2,2), 
                           pool_strides=(2,2))
    
    layer = tf.nn.relu(layer)
    
    layer = conv2d_maxpool(x_tensor=x, 
                       conv_num_outputs=10, 
                       conv_ksize=(2,2), 
                       conv_strides=(4,4), 
                       pool_ksize=(2,2), 
                       pool_strides=(2,2))
    
    layer = tf.nn.relu(layer)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    layer = flatten(layer)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    layer = fully_conn(layer, 100)
    layer = tf.nn.relu(layer)
    layer = fully_conn(layer, 50)
    layer = tf.nn.relu(layer)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    
    # TODO: return output
    
    layer = output(layer, n_classes)
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    print ("Batch Accuracy:", \
    session.run(accuracy, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.}))    
    
    print ("Validation Accuracy:", \
        session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.}))    
    print ("\n")

    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 256
keep_probability = 1.0

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Batch Accuracy: 0.2
# Validation Accuracy: 0.1886
#
#
# Epoch  2, CIFAR-10 Batch 1:  Batch Accuracy: 0.225
# Validation Accuracy: 0.2186
#
#
# Epoch  3, CIFAR-10 Batch 1:  Batch Accuracy: 0.275
# Validation Accuracy: 0.2584
#
#
# Epoch  4, CIFAR-10 Batch 1:  Batch Accuracy: 0.375
# Validation Accuracy: 0.3134
#
#
# Epoch  5, CIFAR-10 Batch 1:  Batch Accuracy: 0.325
# Validation Accuracy: 0.3534
#
#
# Epoch  6, CIFAR-10 Batch 1:  Batch Accuracy: 0.4
# Validation Accuracy: 0.372
#
#
# Epoch  7, CIFAR-10 Batch 1:  Batch Accuracy: 0.425
# Validation Accuracy: 0.387
#
#
# Epoch  8, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.3982
#
#
# Epoch  9, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4062
#
#
# Epoch 10, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4118
#
#
# Epoch 11, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4204
#
#
# Epoch 12, CIFAR-10 Batch 1:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4242
#
#
# Epoch 13, CIFAR-10 Batch 1:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4252
#
#
# Epoch 14, CIFAR-10 Batch 1:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4254
#
#
# Epoch 15, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4304
#
#
# Epoch 16, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4318
#
#
# Epoch 17, CIFAR-10 Batch 1:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4382
#
#
# Epoch 18, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4366
#
#
# Epoch 19, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4402
#
#
# Epoch 20, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.44
#
#
# Epoch 21, CIFAR-10 Batch 1:  Batch Accuracy: 0.7
# Validation Accuracy: 0.4382
#
#
# Epoch 22, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.44
#
#
# Epoch 23, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4398
#
#
# Epoch 24, CIFAR-10 Batch 1:  Batch Accuracy: 0.7
# Validation Accuracy: 0.4414
#
#
# Epoch 25, CIFAR-10 Batch 1:  Batch Accuracy: 0.725
# Validation Accuracy: 0.442
#
#
# Epoch 26, CIFAR-10 Batch 1:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4402
#
#
# Epoch 27, CIFAR-10 Batch 1:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4396
#
#
# Epoch 28, CIFAR-10 Batch 1:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4416
#
#
# Epoch 29, CIFAR-10 Batch 1:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4428
#
#
# Epoch 30, CIFAR-10 Batch 1:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4436
#
#
# Epoch 31, CIFAR-10 Batch 1:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4416
#
#
# Epoch 32, CIFAR-10 Batch 1:  Batch Accuracy: 0.8
# Validation Accuracy: 0.444
#
#
# Epoch 33, CIFAR-10 Batch 1:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4428
#
#
# Epoch 34, CIFAR-10 Batch 1:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4448
#
#
# Epoch 35, CIFAR-10 Batch 1:  Batch Accuracy: 0.85
# Validation Accuracy: 0.4442
#
#
# Epoch 36, CIFAR-10 Batch 1:  Batch Accuracy: 0.85
# Validation Accuracy: 0.4448
#
#
# Epoch 37, CIFAR-10 Batch 1:  Batch Accuracy: 0.85
# Validation Accuracy: 0.4428
#
#
# Epoch 38, CIFAR-10 Batch 1:  Batch Accuracy: 0.85
# Validation Accuracy: 0.44
#
#
# Epoch 39, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.439
#
#
# Epoch 40, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4384
#
#
# Epoch 41, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4396
#
#
# Epoch 42, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4408
#
#
# Epoch 43, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4398
#
#
# Epoch 44, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4422
#
#
# Epoch 45, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4456
#
#
# Epoch 46, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4446
#
#
# Epoch 47, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4488
#
#
# Epoch 48, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.448
#
#
# Epoch 49, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4484
#
#
# Epoch 50, CIFAR-10 Batch 1:  Batch Accuracy: 0.875
# Validation Accuracy: 0.4476

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Batch Accuracy: 0.125
# Validation Accuracy: 0.1534
#
#
# Epoch  1, CIFAR-10 Batch 2:  Batch Accuracy: 0.05
# Validation Accuracy: 0.1826
#
#
# Epoch  1, CIFAR-10 Batch 3:  Batch Accuracy: 0.1
# Validation Accuracy: 0.1914
#
#
# Epoch  1, CIFAR-10 Batch 4:  Batch Accuracy: 0.275
# Validation Accuracy: 0.201
#
#
# Epoch  1, CIFAR-10 Batch 5:  Batch Accuracy: 0.225
# Validation Accuracy: 0.2242
#
#
# Epoch  2, CIFAR-10 Batch 1:  Batch Accuracy: 0.35
# Validation Accuracy: 0.2524
#
#
# Epoch  2, CIFAR-10 Batch 2:  Batch Accuracy: 0.125
# Validation Accuracy: 0.2588
#
#
# Epoch  2, CIFAR-10 Batch 3:  Batch Accuracy: 0.2
# Validation Accuracy: 0.2732
#
#
# Epoch  2, CIFAR-10 Batch 4:  Batch Accuracy: 0.375
# Validation Accuracy: 0.2672
#
#
# Epoch  2, CIFAR-10 Batch 5:  Batch Accuracy: 0.3
# Validation Accuracy: 0.3016
#
#
# Epoch  3, CIFAR-10 Batch 1:  Batch Accuracy: 0.3
# Validation Accuracy: 0.3138
#
#
# Epoch  3, CIFAR-10 Batch 2:  Batch Accuracy: 0.275
# Validation Accuracy: 0.3028
#
#
# Epoch  3, CIFAR-10 Batch 3:  Batch Accuracy: 0.325
# Validation Accuracy: 0.3264
#
#
# Epoch  3, CIFAR-10 Batch 4:  Batch Accuracy: 0.375
# Validation Accuracy: 0.3298
#
#
# Epoch  3, CIFAR-10 Batch 5:  Batch Accuracy: 0.375
# Validation Accuracy: 0.3422
#
#
# Epoch  4, CIFAR-10 Batch 1:  Batch Accuracy: 0.35
# Validation Accuracy: 0.3546
#
#
# Epoch  4, CIFAR-10 Batch 2:  Batch Accuracy: 0.275
# Validation Accuracy: 0.3374
#
#
# Epoch  4, CIFAR-10 Batch 3:  Batch Accuracy: 0.375
# Validation Accuracy: 0.3484
#
#
# Epoch  4, CIFAR-10 Batch 4:  Batch Accuracy: 0.425
# Validation Accuracy: 0.3572
#
#
# Epoch  4, CIFAR-10 Batch 5:  Batch Accuracy: 0.4
# Validation Accuracy: 0.357
#
#
# Epoch  5, CIFAR-10 Batch 1:  Batch Accuracy: 0.4
# Validation Accuracy: 0.3742
#
#
# Epoch  5, CIFAR-10 Batch 2:  Batch Accuracy: 0.35
# Validation Accuracy: 0.3466
#
#
# Epoch  5, CIFAR-10 Batch 3:  Batch Accuracy: 0.375
# Validation Accuracy: 0.3558
#
#
# Epoch  5, CIFAR-10 Batch 4:  Batch Accuracy: 0.45
# Validation Accuracy: 0.372
#
#
# Epoch  5, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.3726
#
#
# Epoch  6, CIFAR-10 Batch 1:  Batch Accuracy: 0.475
# Validation Accuracy: 0.385
#
#
# Epoch  6, CIFAR-10 Batch 2:  Batch Accuracy: 0.35
# Validation Accuracy: 0.3614
#
#
# Epoch  6, CIFAR-10 Batch 3:  Batch Accuracy: 0.375
# Validation Accuracy: 0.374
#
#
# Epoch  6, CIFAR-10 Batch 4:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3816
#
#
# Epoch  6, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.38
#
#
# Epoch  7, CIFAR-10 Batch 1:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3856
#
#
# Epoch  7, CIFAR-10 Batch 2:  Batch Accuracy: 0.35
# Validation Accuracy: 0.3668
#
#
# Epoch  7, CIFAR-10 Batch 3:  Batch Accuracy: 0.4
# Validation Accuracy: 0.383
#
#
# Epoch  7, CIFAR-10 Batch 4:  Batch Accuracy: 0.45
# Validation Accuracy: 0.385
#
#
# Epoch  7, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.3864
#
#
# Epoch  8, CIFAR-10 Batch 1:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3898
#
#
# Epoch  8, CIFAR-10 Batch 2:  Batch Accuracy: 0.35
# Validation Accuracy: 0.3764
#
#
# Epoch  8, CIFAR-10 Batch 3:  Batch Accuracy: 0.45
# Validation Accuracy: 0.3854
#
#
# Epoch  8, CIFAR-10 Batch 4:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3872
#
#
# Epoch  8, CIFAR-10 Batch 5:  Batch Accuracy: 0.4
# Validation Accuracy: 0.3902
#
#
# Epoch  9, CIFAR-10 Batch 1:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3948
#
#
# Epoch  9, CIFAR-10 Batch 2:  Batch Accuracy: 0.425
# Validation Accuracy: 0.3818
#
#
# Epoch  9, CIFAR-10 Batch 3:  Batch Accuracy: 0.45
# Validation Accuracy: 0.3952
#
#
# Epoch  9, CIFAR-10 Batch 4:  Batch Accuracy: 0.5
# Validation Accuracy: 0.3906
#
#
# Epoch  9, CIFAR-10 Batch 5:  Batch Accuracy: 0.425
# Validation Accuracy: 0.3924
#
#
# Epoch 10, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.398
#
#
# Epoch 10, CIFAR-10 Batch 2:  Batch Accuracy: 0.425
# Validation Accuracy: 0.3862
#
#
# Epoch 10, CIFAR-10 Batch 3:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3938
#
#
# Epoch 10, CIFAR-10 Batch 4:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3928
#
#
# Epoch 10, CIFAR-10 Batch 5:  Batch Accuracy: 0.4
# Validation Accuracy: 0.4012
#
#
# Epoch 11, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4028
#
#
# Epoch 11, CIFAR-10 Batch 2:  Batch Accuracy: 0.4
# Validation Accuracy: 0.388
#
#
# Epoch 11, CIFAR-10 Batch 3:  Batch Accuracy: 0.45
# Validation Accuracy: 0.4
#
#
# Epoch 11, CIFAR-10 Batch 4:  Batch Accuracy: 0.525
# Validation Accuracy: 0.3982
#
#
# Epoch 11, CIFAR-10 Batch 5:  Batch Accuracy: 0.4
# Validation Accuracy: 0.4054
#
#
# Epoch 12, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4012
#
#
# Epoch 12, CIFAR-10 Batch 2:  Batch Accuracy: 0.45
# Validation Accuracy: 0.3914
#
#
# Epoch 12, CIFAR-10 Batch 3:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4018
#
#
# Epoch 12, CIFAR-10 Batch 4:  Batch Accuracy: 0.525
# Validation Accuracy: 0.3982
#
#
# Epoch 12, CIFAR-10 Batch 5:  Batch Accuracy: 0.4
# Validation Accuracy: 0.4102
#
#
# Epoch 13, CIFAR-10 Batch 1:  Batch Accuracy: 0.5
# Validation Accuracy: 0.412
#
#
# Epoch 13, CIFAR-10 Batch 2:  Batch Accuracy: 0.4
# Validation Accuracy: 0.3904
#
#
# Epoch 13, CIFAR-10 Batch 3:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4018
#
#
# Epoch 13, CIFAR-10 Batch 4:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4004
#
#
# Epoch 13, CIFAR-10 Batch 5:  Batch Accuracy: 0.4
# Validation Accuracy: 0.4156
#
#
# Epoch 14, CIFAR-10 Batch 1:  Batch Accuracy: 0.525
# Validation Accuracy: 0.4126
#
#
# Epoch 14, CIFAR-10 Batch 2:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3918
#
#
# Epoch 14, CIFAR-10 Batch 3:  Batch Accuracy: 0.5
# Validation Accuracy: 0.402
#
#
# Epoch 14, CIFAR-10 Batch 4:  Batch Accuracy: 0.525
# Validation Accuracy: 0.4056
#
#
# Epoch 14, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.4176
#
#
# Epoch 15, CIFAR-10 Batch 1:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4152
#
#
# Epoch 15, CIFAR-10 Batch 2:  Batch Accuracy: 0.475
# Validation Accuracy: 0.3938
#
#
# Epoch 15, CIFAR-10 Batch 3:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4032
#
#
# Epoch 15, CIFAR-10 Batch 4:  Batch Accuracy: 0.525
# Validation Accuracy: 0.4086
#
#
# Epoch 15, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.4178
#
#
# Epoch 16, CIFAR-10 Batch 1:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4162
#
#
# Epoch 16, CIFAR-10 Batch 2:  Batch Accuracy: 0.525
# Validation Accuracy: 0.3964
#
#
# Epoch 16, CIFAR-10 Batch 3:  Batch Accuracy: 0.5
# Validation Accuracy: 0.4054
#
#
# Epoch 16, CIFAR-10 Batch 4:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4122
#
#
# Epoch 16, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.4202
#
#
# Epoch 17, CIFAR-10 Batch 1:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4176
#
#
# Epoch 17, CIFAR-10 Batch 2:  Batch Accuracy: 0.575
# Validation Accuracy: 0.3984
#
#
# Epoch 17, CIFAR-10 Batch 3:  Batch Accuracy: 0.525
# Validation Accuracy: 0.4088
#
#
# Epoch 17, CIFAR-10 Batch 4:  Batch Accuracy: 0.575
# Validation Accuracy: 0.4128
#
#
# Epoch 17, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.4206
#
#
# Epoch 18, CIFAR-10 Batch 1:  Batch Accuracy: 0.525
# Validation Accuracy: 0.415
#
#
# Epoch 18, CIFAR-10 Batch 2:  Batch Accuracy: 0.575
# Validation Accuracy: 0.4
#
#
# Epoch 18, CIFAR-10 Batch 3:  Batch Accuracy: 0.525
# Validation Accuracy: 0.446
#
#
# Epoch 18, CIFAR-10 Batch 4:  Batch Accuracy: 0.65
# Validation Accuracy: 0.454
#
#
# Epoch 18, CIFAR-10 Batch 5:  Batch Accuracy: 0.45
# Validation Accuracy: 0.461
#
#
# Epoch 19, CIFAR-10 Batch 1:  Batch Accuracy: 0.575
# Validation Accuracy: 0.453
#
#
# Epoch 19, CIFAR-10 Batch 2:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4318
#
#
# Epoch 19, CIFAR-10 Batch 3:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4584
#
#
# Epoch 19, CIFAR-10 Batch 4:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4618
#
#
# Epoch 19, CIFAR-10 Batch 5:  Batch Accuracy: 0.475
# Validation Accuracy: 0.4692
#
#
# Epoch 20, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4622
#
#
# Epoch 20, CIFAR-10 Batch 2:  Batch Accuracy: 0.625
# Validation Accuracy: 0.437
#
#
# Epoch 20, CIFAR-10 Batch 3:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4628
#
#
# Epoch 20, CIFAR-10 Batch 4:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4618
#
#
# Epoch 20, CIFAR-10 Batch 5:  Batch Accuracy: 0.525
# Validation Accuracy: 0.4704
#
#
# Epoch 21, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4612
#
#
# Epoch 21, CIFAR-10 Batch 2:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4412
#
#
# Epoch 21, CIFAR-10 Batch 3:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4648
#
#
# Epoch 21, CIFAR-10 Batch 4:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4666
#
#
# Epoch 21, CIFAR-10 Batch 5:  Batch Accuracy: 0.55
# Validation Accuracy: 0.4692
#
#
# Epoch 22, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4662
#
#
# Epoch 22, CIFAR-10 Batch 2:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4438
#
#
# Epoch 22, CIFAR-10 Batch 3:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4672
#
#
# Epoch 22, CIFAR-10 Batch 4:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4694
#
#
# Epoch 22, CIFAR-10 Batch 5:  Batch Accuracy: 0.575
# Validation Accuracy: 0.472
#
#
# Epoch 23, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4716
#
#
# Epoch 23, CIFAR-10 Batch 2:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4432
#
#
# Epoch 23, CIFAR-10 Batch 3:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4684
#
#
# Epoch 23, CIFAR-10 Batch 4:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4744
#
#
# Epoch 23, CIFAR-10 Batch 5:  Batch Accuracy: 0.575
# Validation Accuracy: 0.4754
#
#
# Epoch 24, CIFAR-10 Batch 1:  Batch Accuracy: 0.6
# Validation Accuracy: 0.4704
#
#
# Epoch 24, CIFAR-10 Batch 2:  Batch Accuracy: 0.7
# Validation Accuracy: 0.4516
#
#
# Epoch 24, CIFAR-10 Batch 3:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4688
#
#
# Epoch 24, CIFAR-10 Batch 4:  Batch Accuracy: 0.7
# Validation Accuracy: 0.4724
#
#
# Epoch 24, CIFAR-10 Batch 5:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4744
#
#
# Epoch 25, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4748
#
#
# Epoch 25, CIFAR-10 Batch 2:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4514
#
#
# Epoch 25, CIFAR-10 Batch 3:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4698
#
#
# Epoch 25, CIFAR-10 Batch 4:  Batch Accuracy: 0.725
# Validation Accuracy: 0.474
#
#
# Epoch 25, CIFAR-10 Batch 5:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4786
#
#
# Epoch 26, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4732
#
#
# Epoch 26, CIFAR-10 Batch 2:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4554
#
#
# Epoch 26, CIFAR-10 Batch 3:  Batch Accuracy: 0.675
# Validation Accuracy: 0.471
#
#
# Epoch 26, CIFAR-10 Batch 4:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4756
#
#
# Epoch 26, CIFAR-10 Batch 5:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4826
#
#
# Epoch 27, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4762
#
#
# Epoch 27, CIFAR-10 Batch 2:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4546
#
#
# Epoch 27, CIFAR-10 Batch 3:  Batch Accuracy: 0.675
# Validation Accuracy: 0.474
#
#
# Epoch 27, CIFAR-10 Batch 4:  Batch Accuracy: 0.725
# Validation Accuracy: 0.473
#
#
# Epoch 27, CIFAR-10 Batch 5:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4832
#
#
# Epoch 28, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.478
#
#
# Epoch 28, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4588
#
#
# Epoch 28, CIFAR-10 Batch 3:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4736
#
#
# Epoch 28, CIFAR-10 Batch 4:  Batch Accuracy: 0.725
# Validation Accuracy: 0.476
#
#
# Epoch 28, CIFAR-10 Batch 5:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4798
#
#
# Epoch 29, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.48
#
#
# Epoch 29, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4608
#
#
# Epoch 29, CIFAR-10 Batch 3:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4744
#
#
# Epoch 29, CIFAR-10 Batch 4:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4768
#
#
# Epoch 29, CIFAR-10 Batch 5:  Batch Accuracy: 0.675
# Validation Accuracy: 0.481
#
#
# Epoch 30, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4812
#
#
# Epoch 30, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4624
#
#
# Epoch 30, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4758
#
#
# Epoch 30, CIFAR-10 Batch 4:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4818
#
#
# Epoch 30, CIFAR-10 Batch 5:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4876
#
#
# Epoch 31, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.482
#
#
# Epoch 31, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4652
#
#
# Epoch 31, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4772
#
#
# Epoch 31, CIFAR-10 Batch 4:  Batch Accuracy: 0.825
# Validation Accuracy: 0.482
#
#
# Epoch 31, CIFAR-10 Batch 5:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4888
#
#
# Epoch 32, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4806
#
#
# Epoch 32, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4666
#
#
# Epoch 32, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4824
#
#
# Epoch 32, CIFAR-10 Batch 4:  Batch Accuracy: 0.825
# Validation Accuracy: 0.4802
#
#
# Epoch 32, CIFAR-10 Batch 5:  Batch Accuracy: 0.7
# Validation Accuracy: 0.4918
#
#
# Epoch 33, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.484
#
#
# Epoch 33, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4724
#
#
# Epoch 33, CIFAR-10 Batch 3:  Batch Accuracy: 0.7
# Validation Accuracy: 0.4834
#
#
# Epoch 33, CIFAR-10 Batch 4:  Batch Accuracy: 0.825
# Validation Accuracy: 0.4826
#
#
# Epoch 33, CIFAR-10 Batch 5:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4932
#
#
# Epoch 34, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4872
#
#
# Epoch 34, CIFAR-10 Batch 2:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4746
#
#
# Epoch 34, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4866
#
#
# Epoch 34, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4828
#
#
# Epoch 34, CIFAR-10 Batch 5:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4918
#
#
# Epoch 35, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.488
#
#
# Epoch 35, CIFAR-10 Batch 2:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4744
#
#
# Epoch 35, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4888
#
#
# Epoch 35, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4858
#
#
# Epoch 35, CIFAR-10 Batch 5:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4932
#
#
# Epoch 36, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.487
#
#
# Epoch 36, CIFAR-10 Batch 2:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4738
#
#
# Epoch 36, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4878
#
#
# Epoch 36, CIFAR-10 Batch 4:  Batch Accuracy: 0.825
# Validation Accuracy: 0.488
#
#
# Epoch 36, CIFAR-10 Batch 5:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4954
#
#
# Epoch 37, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4904
#
#
# Epoch 37, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4784
#
#
# Epoch 37, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4904
#
#
# Epoch 37, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4894
#
#
# Epoch 37, CIFAR-10 Batch 5:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4948
#
#
# Epoch 38, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.492
#
#
# Epoch 38, CIFAR-10 Batch 2:  Batch Accuracy: 0.775
# Validation Accuracy: 0.48
#
#
# Epoch 38, CIFAR-10 Batch 3:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4924
#
#
# Epoch 38, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4886
#
#
# Epoch 38, CIFAR-10 Batch 5:  Batch Accuracy: 0.725
# Validation Accuracy: 0.493
#
#
# Epoch 39, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4892
#
#
# Epoch 39, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4836
#
#
# Epoch 39, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4922
#
#
# Epoch 39, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4908
#
#
# Epoch 39, CIFAR-10 Batch 5:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4948
#
#
# Epoch 40, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4928
#
#
# Epoch 40, CIFAR-10 Batch 2:  Batch Accuracy: 0.825
# Validation Accuracy: 0.485
#
#
# Epoch 40, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4934
#
#
# Epoch 40, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4924
#
#
# Epoch 40, CIFAR-10 Batch 5:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4942
#
#
# Epoch 41, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4932
#
#
# Epoch 41, CIFAR-10 Batch 2:  Batch Accuracy: 0.85
# Validation Accuracy: 0.484
#
#
# Epoch 41, CIFAR-10 Batch 3:  Batch Accuracy: 0.725
# Validation Accuracy: 0.4972
#
#
# Epoch 41, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4952
#
#
# Epoch 41, CIFAR-10 Batch 5:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4942
#
#
# Epoch 42, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4934
#
#
# Epoch 42, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4866
#
#
# Epoch 42, CIFAR-10 Batch 3:  Batch Accuracy: 0.75
# Validation Accuracy: 0.497
#
#
# Epoch 42, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4956
#
#
# Epoch 42, CIFAR-10 Batch 5:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4922
#
#
# Epoch 43, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4948
#
#
# Epoch 43, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4914
#
#
# Epoch 43, CIFAR-10 Batch 3:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4988
#
#
# Epoch 43, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4988
#
#
# Epoch 43, CIFAR-10 Batch 5:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4938
#
#
# Epoch 44, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4958
#
#
# Epoch 44, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4918
#
#
# Epoch 44, CIFAR-10 Batch 3:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4984
#
#
# Epoch 44, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.5014
#
#
# Epoch 44, CIFAR-10 Batch 5:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4946
#
#
# Epoch 45, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4956
#
#
# Epoch 45, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4924
#
#
# Epoch 45, CIFAR-10 Batch 3:  Batch Accuracy: 0.775
# Validation Accuracy: 0.498
#
#
# Epoch 45, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.5
#
#
# Epoch 45, CIFAR-10 Batch 5:  Batch Accuracy: 0.75
# Validation Accuracy: 0.4932
#
#
# Epoch 46, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4992
#
#
# Epoch 46, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4936
#
#
# Epoch 46, CIFAR-10 Batch 3:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4966
#
#
# Epoch 46, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.498
#
#
# Epoch 46, CIFAR-10 Batch 5:  Batch Accuracy: 0.8
# Validation Accuracy: 0.495
#
#
# Epoch 47, CIFAR-10 Batch 1:  Batch Accuracy: 0.675
# Validation Accuracy: 0.4974
#
#
# Epoch 47, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4954
#
#
# Epoch 47, CIFAR-10 Batch 3:  Batch Accuracy: 0.825
# Validation Accuracy: 0.4984
#
#
# Epoch 47, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4982
#
#
# Epoch 47, CIFAR-10 Batch 5:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4968
#
#
# Epoch 48, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4956
#
#
# Epoch 48, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.4984
#
#
# Epoch 48, CIFAR-10 Batch 3:  Batch Accuracy: 0.85
# Validation Accuracy: 0.498
#
#
# Epoch 48, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.501
#
#
# Epoch 48, CIFAR-10 Batch 5:  Batch Accuracy: 0.775
# Validation Accuracy: 0.4964
#
#
# Epoch 49, CIFAR-10 Batch 1:  Batch Accuracy: 0.625
# Validation Accuracy: 0.4948
#
#
# Epoch 49, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.5002
#
#
# Epoch 49, CIFAR-10 Batch 3:  Batch Accuracy: 0.85
# Validation Accuracy: 0.5004
#
#
# Epoch 49, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.5002
#
#
# Epoch 49, CIFAR-10 Batch 5:  Batch Accuracy: 0.825
# Validation Accuracy: 0.4988
#
#
# Epoch 50, CIFAR-10 Batch 1:  Batch Accuracy: 0.65
# Validation Accuracy: 0.4948
#
#
# Epoch 50, CIFAR-10 Batch 2:  Batch Accuracy: 0.8
# Validation Accuracy: 0.5016
#
#
# Epoch 50, CIFAR-10 Batch 3:  Batch Accuracy: 0.85
# Validation Accuracy: 0.5
#
#
# Epoch 50, CIFAR-10 Batch 4:  Batch Accuracy: 0.8
# Validation Accuracy: 0.502
#
#
# Epoch 50, CIFAR-10 Batch 5:  Batch Accuracy: 0.825
# Validation Accuracy: 0.4986

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5005859375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
